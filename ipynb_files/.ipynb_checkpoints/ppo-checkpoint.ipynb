# %%
from functional import *
# Out:
# 2024-10-20 21:39:14.787102: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-20 21:39:14.798261: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-20 21:39:14.801429: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-20 21:39:14.809929: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
ppo=agent('PPO','MlpPolicy')
# Out:
# /home/golderalex2/Downloads/statistic/python/reinforce_trading/trading_environment.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['Diff_pct']=self.df['Close'].pct_change(1).fillna(0)*100
# /home/golderalex2/Downloads/statistic/python/reinforce_trading/trading_environment.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['Diff_pct']=self.df['Close'].pct_change(1).fillna(0)*100
# Using normal policy !!
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# ...

# %%
ppo.learn()
# Out:
# /py_virtual/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 31.3     |
# | time/              |          |
# |    fps             | 2107     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 1530        |
# |    iterations           | 2           |
# ...

# %%
ppo.evaluate()
# Out:
# /py_virtual/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.total to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.total` for environment variables or `env.get_wrapper_attr('total')` that will search the reminding wrappers.
#   logger.warn(
# Max drawdown      61.969437
# PnL             5596.655330
# ROI               55.966553
# dtype: float64

# %%
ppo.visualize()
