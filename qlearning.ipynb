# %%
from functional import *
# Out:
# 2024-10-19 13:08:24.445943: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-19 13:08:24.456783: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-19 13:08:24.459762: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-19 13:08:24.468141: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-19 13:08:25.090013: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
with open(os.path.join(Path().cwd(),'parameters.json'),'r+') as f:
          parameter=json.loads(f.read())
          start_date=parameter['start_date']
          test_date=parameter['test_date']
          end_date=parameter['end_date']
df=pd.read_csv('data/SPX/SPX_1d.csv',index_col=0)
df_train=df.loc[start_date:test_date]
df_test=df.loc[test_date:end_date]

# %%
class ql_agent():
    def __init__(self,env,qtable_height=40,qtable_width=10,learning_rate=0.1,discount_value=0.9,epochs=1000,epsilon=0.99,epsilon_decay=0.99,overflow=0.05):
        self.learning_rate=learning_rate
        self.discount_value=discount_value
        self.epochs=epochs
        self.epsilon=epsilon
        self.epsilon_decay=epsilon_decay
        self.env=env
        self.overflow=overflow
        self.qtable_height=qtable_height
        self.qtable_width=qtable_width
    
    def create_qtable(self):
        self.qtable_size=(self.qtable_height,self.qtable_width)
        self.qtable_segment_size=(self.env.observation_max*(1+self.overflow)-self.env.observation_min*(1-self.overflow))/np.array(self.qtable_size)
        self.qtable=np.random.uniform(low=-2,high=0,size=self.qtable_size+(3,))

    def convert_state(self,current_state):
        return tuple(((current_state-self.env.observation_min*(1-self.overflow))/self.qtable_segment_size).astype(int))
    
    def update_qtable(self,current_state,new_state,reward,action):
        current_q_value=self.qtable[current_state+(action,)]

        new_state=new_state[0]
        new_state=self.convert_state(new_state)
        new_q_value=(1-self.learning_rate) * current_q_value+self.learning_rate*reward
        self.qtable[current_state + (action,)] = new_q_value
    
    def decide(self,current_state):
        return np.argmax(self.qtable[current_state])

    def train(self):
        self.create_qtable()
        self.best_portforlio_value=-9999999
        self.action_list=None
        self.portforlio_history=None

        for epoch in range(self.epochs):

            print(f'Epoch :{epoch}')
            current_state,_=self.env.reset()
            current_state=current_state[0]
            current_state=self.convert_state(current_state)

            epoch_portforlio_value=None
            epoch_actions_list=[]
            epoch_portforlio_history=[]

            while True:
                if np.random.uniform(0,1,size=1)[0]<self.epsilon:
                    action=np.random.randint(0,2)
                else:
                    action=self.decide(current_state)
                new_state,reward,terminate,truncate,_=self.env.step(action)
                self.update_qtable(current_state,new_state,reward,action)

                current_state=new_state
                current_state=current_state[0]
                current_state=self.convert_state(current_state)

                epoch_portforlio_history.append(self.env.total)
                epoch_actions_list.append(action)

                if terminate:
                    epoch_portforlio_value=self.env.total
                    if self.best_portforlio_value<epoch_portforlio_value:
                        self.best_portforlio_value=epoch_portforlio_value
                        self.action_list=epoch_actions_list
                        self.portforlio_history=epoch_portforlio_history
                    break
            self.epsilon*=self.epsilon_decay
            print(f'Portforlio value :{round(epoch_portforlio_value,3)},number of actions :{len(epoch_actions_list)}')

# %%
env=trading_env(df_train,1)
agen=ql_agent(env,epochs=500,qtable_height=300,qtable_width=100)
# Out:
# /home/golderalex2/Downloads/statistic/python/reinforce_trading/trading_environment.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['Diff_pct']=self.df['Close'].pct_change(1).fillna(0)*100

# %%
agen.train()
# Out:
# Epoch :0
# Portforlio value :13048.794,number of actions :1195
# Epoch :1
# Portforlio value :13135.619,number of actions :1195
# Epoch :2
# Portforlio value :13070.422,number of actions :1195
# Epoch :3
# Portforlio value :12846.124,number of actions :1195
# Epoch :4
# Portforlio value :12789.381,number of actions :1195
# Epoch :5
# Portforlio value :13002.733,number of actions :1195
# Epoch :6
# Portforlio value :12937.895,number of actions :1195
# Epoch :7
# Portforlio value :13336.207,number of actions :1195
# Epoch :8
# Portforlio value :13140.437,number of actions :1195
# Epoch :9
# Portforlio value :12995.349,number of actions :1195
# Epoch :10
# Portforlio value :13205.488,number of actions :1195
# Epoch :11
# Portforlio value :13220.41,number of actions :1195
# Epoch :12
# Portforlio value :13103.739,number of actions :1195
# Epoch :13
# Portforlio value :13131.39,number of actions :1195
# Epoch :14
# Portforlio value :13242.105,number of actions :1195
# Epoch :15
# Portforlio value :13361.524,number of actions :1195
# Epoch :16
# Portforlio value :13213.538,number of actions :1195
# Epoch :17
# Portforlio value :13088.226,number of actions :1195
# Epoch :18
# Portforlio value :13198.419,number of actions :1195
# Epoch :19
# Portforlio value :13551.673,number of actions :1195
# Epoch :20
# Portforlio value :13121.528,number of actions :1195
# Epoch :21
# Portforlio value :13507.318,number of actions :1195
# Epoch :22
# Portforlio value :13150.969,number of actions :1195
# Epoch :23
# Portforlio value :13156.544,number of actions :1195
# Epoch :24
# Portforlio value :13076.6,number of actions :1195
# Epoch :25
# Portforlio value :13310.05,number of actions :1195
# Epoch :26
# Portforlio value :13393.625,number of actions :1195
# Epoch :27
# Portforlio value :13264.518,number of actions :1195
# Epoch :28
# Portforlio value :13647.745,number of actions :1195
# Epoch :29
# Portforlio value :13609.142,number of actions :1195
# Epoch :30
# Portforlio value :13561.523,number of actions :1195
# Epoch :31
# Portforlio value :13544.445,number of actions :1195
# Epoch :32
# Portforlio value :13297.924,number of actions :1195
# Epoch :33
# Portforlio value :13980.281,number of actions :1195
# Epoch :34
# Portforlio value :13573.729,number of actions :1195
# Epoch :35
# Portforlio value :13617.206,number of actions :1195
# Epoch :36
# Portforlio value :13731.649,number of actions :1195
# Epoch :37
# Portforlio value :13383.353,number of actions :1195
# Epoch :38
# Portforlio value :13534.525,number of actions :1195
# Epoch :39
# Portforlio value :13484.429,number of actions :1195
# Epoch :40
# Portforlio value :13434.955,number of actions :1195
# Epoch :41
# Portforlio value :13855.347,number of actions :1195
# Epoch :42
# Portforlio value :13992.962,number of actions :1195
# Epoch :43
# Portforlio value :13672.512,number of actions :1195
# Epoch :44
# Portforlio value :14195.268,number of actions :1195
# Epoch :45
# Portforlio value :13620.826,number of actions :1195
# Epoch :46
# Portforlio value :14114.077,number of actions :1195
# Epoch :47
# Portforlio value :13301.612,number of actions :1195
# Epoch :48
# Portforlio value :13320.722,number of actions :1195
# Epoch :49
# Portforlio value :13857.763,number of actions :1195
# Epoch :50
# Portforlio value :13360.641,number of actions :1195
# Epoch :51
# Portforlio value :13863.027,number of actions :1195
# Epoch :52
# Portforlio value :13776.674,number of actions :1195
# Epoch :53
# Portforlio value :13867.228,number of actions :1195
# Epoch :54
# Portforlio value :13518.218,number of actions :1195
# Epoch :55
# Portforlio value :14540.505,number of actions :1195
# Epoch :56
# Portforlio value :13930.375,number of actions :1195
# Epoch :57
# Portforlio value :13668.453,number of actions :1195
# Epoch :58
# Portforlio value :13657.29,number of actions :1195
# Epoch :59
# Portforlio value :14042.127,number of actions :1195
# Epoch :60
# Portforlio value :14505.694,number of actions :1195
# Epoch :61
# Portforlio value :13432.805,number of actions :1195
# Epoch :62
# Portforlio value :13530.541,number of actions :1195
# Epoch :63
# Portforlio value :13913.909,number of actions :1195
# Epoch :64
# Portforlio value :13963.025,number of actions :1195
# Epoch :65
# Portforlio value :13546.416,number of actions :1195
# Epoch :66
# Portforlio value :13373.071,number of actions :1195
# Epoch :67
# Portforlio value :14025.398,number of actions :1195
# Epoch :68
# Portforlio value :13644.176,number of actions :1195
# Epoch :69
# Portforlio value :13345.149,number of actions :1195
# Epoch :70
# Portforlio value :13764.816,number of actions :1195
# Epoch :71
# Portforlio value :13949.975,number of actions :1195
# Epoch :72
# Portforlio value :13631.598,number of actions :1195
# Epoch :73
# Portforlio value :13831.166,number of actions :1195
# Epoch :74
# Portforlio value :13647.091,number of actions :1195
# Epoch :75
# Portforlio value :13534.862,number of actions :1195
# Epoch :76
# Portforlio value :13393.396,number of actions :1195
# Epoch :77
# Portforlio value :13622.877,number of actions :1195
# Epoch :78
# Portforlio value :13788.026,number of actions :1195
# Epoch :79
# Portforlio value :14003.687,number of actions :1195
# Epoch :80
# Portforlio value :13445.653,number of actions :1195
# Epoch :81
# Portforlio value :13506.06,number of actions :1195
# Epoch :82
# Portforlio value :13955.763,number of actions :1195
# Epoch :83
# Portforlio value :13944.13,number of actions :1195
# Epoch :84
# Portforlio value :13935.588,number of actions :1195
# Epoch :85
# Portforlio value :13570.9,number of actions :1195
# Epoch :86
# Portforlio value :13894.101,number of actions :1195
# Epoch :87
# Portforlio value :13443.644,number of actions :1195
# Epoch :88
# Portforlio value :13221.411,number of actions :1195
# Epoch :89
# Portforlio value :13284.844,number of actions :1195
# Epoch :90
# Portforlio value :13495.37,number of actions :1195
# Epoch :91
# Portforlio value :13866.991,number of actions :1195
# Epoch :92
# Portforlio value :13563.973,number of actions :1195
# Epoch :93
# Portforlio value :13464.978,number of actions :1195
# Epoch :94
# Portforlio value :13451.999,number of actions :1195
# Epoch :95
# Portforlio value :13170.252,number of actions :1195
# Epoch :96
# Portforlio value :14053.245,number of actions :1195
# Epoch :97
# Portforlio value :13560.498,number of actions :1195
# Epoch :98
# Portforlio value :13417.649,number of actions :1195
# Epoch :99
# Portforlio value :13658.385,number of actions :1195
# Epoch :100
# Portforlio value :13479.368,number of actions :1195
# Epoch :101
# Portforlio value :13524.121,number of actions :1195
# Epoch :102
# Portforlio value :13962.933,number of actions :1195
# Epoch :103
# Portforlio value :13634.355,number of actions :1195
# Epoch :104
# Portforlio value :13682.4,number of actions :1195
# Epoch :105
# Portforlio value :13511.618,number of actions :1195
# Epoch :106
# Portforlio value :13703.219,number of actions :1195
# Epoch :107
# Portforlio value :13433.363,number of actions :1195
# Epoch :108
# Portforlio value :13463.403,number of actions :1195
# Epoch :109
# Portforlio value :13705.421,number of actions :1195
# Epoch :110
# Portforlio value :13795.408,number of actions :1195
# Epoch :111
# Portforlio value :14305.521,number of actions :1195
# Epoch :112
# Portforlio value :13839.782,number of actions :1195
# Epoch :113
# Portforlio value :13246.774,number of actions :1195
# Epoch :114
# Portforlio value :13451.097,number of actions :1195
# Epoch :115
# Portforlio value :13409.573,number of actions :1195
# Epoch :116
# Portforlio value :13509.339,number of actions :1195
# Epoch :117
# Portforlio value :13389.859,number of actions :1195
# Epoch :118
# Portforlio value :13444.009,number of actions :1195
# Epoch :119
# Portforlio value :13450.188,number of actions :1195
# Epoch :120
# Portforlio value :13206.05,number of actions :1195
# Epoch :121
# Portforlio value :13322.205,number of actions :1195
# Epoch :122
# Portforlio value :13645.974,number of actions :1195
# Epoch :123
# Portforlio value :13424.664,number of actions :1195
# Epoch :124
# Portforlio value :13407.524,number of actions :1195
# Epoch :125
# Portforlio value :13347.163,number of actions :1195
# Epoch :126
# Portforlio value :13578.606,number of actions :1195
# Epoch :127
# Portforlio value :13271.059,number of actions :1195
# Epoch :128
# Portforlio value :13661.773,number of actions :1195
# Epoch :129
# Portforlio value :13539.464,number of actions :1195
# Epoch :130
# Portforlio value :14095.855,number of actions :1195
# Epoch :131
# Portforlio value :13870.48,number of actions :1195
# Epoch :132
# Portforlio value :13385.526,number of actions :1195
# Epoch :133
# Portforlio value :13362.539,number of actions :1195
# Epoch :134
# Portforlio value :13290.205,number of actions :1195
# Epoch :135
# Portforlio value :13256.866,number of actions :1195
# Epoch :136
# Portforlio value :13036.626,number of actions :1195
# Epoch :137
# Portforlio value :13637.591,number of actions :1195
# Epoch :138
# Portforlio value :13410.792,number of actions :1195
# Epoch :139
# Portforlio value :13680.981,number of actions :1195
# Epoch :140
# Portforlio value :13735.213,number of actions :1195
# Epoch :141
# Portforlio value :13490.742,number of actions :1195
# Epoch :142
# Portforlio value :13894.92,number of actions :1195
# Epoch :143
# Portforlio value :14264.838,number of actions :1195
# Epoch :144
# Portforlio value :13541.526,number of actions :1195
# Epoch :145
# Portforlio value :13330.854,number of actions :1195
# Epoch :146
# Portforlio value :13424.404,number of actions :1195
# Epoch :147
# Portforlio value :13465.637,number of actions :1195
# Epoch :148
# Portforlio value :13534.693,number of actions :1195
# Epoch :149
# Portforlio value :13511.96,number of actions :1195
# Epoch :150
# Portforlio value :13282.13,number of actions :1195
# Epoch :151
# Portforlio value :13555.093,number of actions :1195
# Epoch :152
# Portforlio value :13597.97,number of actions :1195
# Epoch :153
# Portforlio value :13290.19,number of actions :1195
# Epoch :154
# Portforlio value :13217.75,number of actions :1195
# Epoch :155
# Portforlio value :13465.533,number of actions :1195
# Epoch :156
# Portforlio value :13226.605,number of actions :1195
# Epoch :157
# Portforlio value :13262.813,number of actions :1195
# Epoch :158
# Portforlio value :13452.003,number of actions :1195
# Epoch :159
# Portforlio value :13349.95,number of actions :1195
# Epoch :160
# Portforlio value :13406.477,number of actions :1195
# Epoch :161
# Portforlio value :13379.185,number of actions :1195
# Epoch :162
# Portforlio value :13367.587,number of actions :1195
# Epoch :163
# Portforlio value :13356.379,number of actions :1195
# Epoch :164
# Portforlio value :13489.895,number of actions :1195
# Epoch :165
# Portforlio value :13305.099,number of actions :1195
# Epoch :166
# Portforlio value :13485.242,number of actions :1195
# Epoch :167
# Portforlio value :13893.6,number of actions :1195
# Epoch :168
# Portforlio value :13781.359,number of actions :1195
# Epoch :169
# Portforlio value :13545.228,number of actions :1195
# Epoch :170
# Portforlio value :13562.305,number of actions :1195
# Epoch :171
# Portforlio value :13609.895,number of actions :1195
# Epoch :172
# Portforlio value :13849.674,number of actions :1195
# Epoch :173
# Portforlio value :13820.376,number of actions :1195
# Epoch :174
# Portforlio value :13525.208,number of actions :1195
# Epoch :175
# Portforlio value :13747.505,number of actions :1195
# Epoch :176
# Portforlio value :13614.64,number of actions :1195
# Epoch :177
# Portforlio value :13404.306,number of actions :1195
# Epoch :178
# Portforlio value :13451.7,number of actions :1195
# Epoch :179
# Portforlio value :13541.886,number of actions :1195
# Epoch :180
# Portforlio value :13344.587,number of actions :1195
# Epoch :181
# Portforlio value :13550.827,number of actions :1195
# Epoch :182
# Portforlio value :13380.03,number of actions :1195
# Epoch :183
# Portforlio value :13452.408,number of actions :1195
# Epoch :184
# Portforlio value :13548.377,number of actions :1195
# Epoch :185
# Portforlio value :13320.843,number of actions :1195
# Epoch :186
# Portforlio value :13865.185,number of actions :1195
# Epoch :187
# Portforlio value :13383.419,number of actions :1195
# Epoch :188
# Portforlio value :13652.304,number of actions :1195
# Epoch :189
# Portforlio value :13644.388,number of actions :1195
# Epoch :190
# Portforlio value :13424.389,number of actions :1195
# Epoch :191
# Portforlio value :13547.471,number of actions :1195
# Epoch :192
# Portforlio value :13504.298,number of actions :1195
# Epoch :193
# Portforlio value :13785.064,number of actions :1195
# Epoch :194
# Portforlio value :13531.187,number of actions :1195
# Epoch :195
# Portforlio value :13363.169,number of actions :1195
# Epoch :196
# Portforlio value :13454.956,number of actions :1195
# Epoch :197
# Portforlio value :13465.042,number of actions :1195
# Epoch :198
# Portforlio value :13182.372,number of actions :1195
# Epoch :199
# Portforlio value :13470.436,number of actions :1195
# Epoch :200
# Portforlio value :13383.343,number of actions :1195
# Epoch :201
# Portforlio value :13526.647,number of actions :1195
# Epoch :202
# Portforlio value :13162.296,number of actions :1195
# Epoch :203
# Portforlio value :13372.176,number of actions :1195
# Epoch :204
# Portforlio value :13539.525,number of actions :1195
# Epoch :205
# Portforlio value :13380.822,number of actions :1195
# Epoch :206
# Portforlio value :13409.559,number of actions :1195
# Epoch :207
# Portforlio value :13576.953,number of actions :1195
# Epoch :208
# Portforlio value :13408.108,number of actions :1195
# Epoch :209
# Portforlio value :13578.73,number of actions :1195
# Epoch :210
# Portforlio value :13611.832,number of actions :1195
# Epoch :211
# Portforlio value :13464.884,number of actions :1195
# Epoch :212
# Portforlio value :13708.171,number of actions :1195
# Epoch :213
# Portforlio value :13685.592,number of actions :1195
# Epoch :214
# Portforlio value :13770.371,number of actions :1195
# Epoch :215
# Portforlio value :13762.861,number of actions :1195
# Epoch :216
# Portforlio value :13683.561,number of actions :1195
# Epoch :217
# Portforlio value :13664.52,number of actions :1195
# Epoch :218
# Portforlio value :14032.835,number of actions :1195
# Epoch :219
# Portforlio value :13917.773,number of actions :1195
# Epoch :220
# Portforlio value :13749.791,number of actions :1195
# Epoch :221
# Portforlio value :13752.932,number of actions :1195
# Epoch :222
# Portforlio value :13691.302,number of actions :1195
# Epoch :223
# Portforlio value :13765.724,number of actions :1195
# Epoch :224
# Portforlio value :13622.296,number of actions :1195
# Epoch :225
# Portforlio value :13891.59,number of actions :1195
# Epoch :226
# Portforlio value :13673.321,number of actions :1195
# Epoch :227
# Portforlio value :13571.809,number of actions :1195
# Epoch :228
# Portforlio value :13945.463,number of actions :1195
# Epoch :229
# Portforlio value :13359.139,number of actions :1195
# Epoch :230
# Portforlio value :13693.764,number of actions :1195
# Epoch :231
# Portforlio value :13781.11,number of actions :1195
# Epoch :232
# Portforlio value :13602.643,number of actions :1195
# Epoch :233
# Portforlio value :13823.467,number of actions :1195
# Epoch :234
# Portforlio value :13708.077,number of actions :1195
# Epoch :235
# Portforlio value :13872.313,number of actions :1195
# Epoch :236
# Portforlio value :13816.213,number of actions :1195
# Epoch :237
# Portforlio value :13521.482,number of actions :1195
# Epoch :238
# Portforlio value :13616.973,number of actions :1195
# Epoch :239
# Portforlio value :13487.418,number of actions :1195
# Epoch :240
# Portforlio value :13772.983,number of actions :1195
# Epoch :241
# Portforlio value :13484.261,number of actions :1195
# Epoch :242
# Portforlio value :13438.012,number of actions :1195
# Epoch :243
# Portforlio value :13526.177,number of actions :1195
# Epoch :244
# Portforlio value :13221.583,number of actions :1195
# Epoch :245
# Portforlio value :13380.853,number of actions :1195
# Epoch :246
# Portforlio value :13366.508,number of actions :1195
# Epoch :247
# Portforlio value :13440.166,number of actions :1195
# Epoch :248
# Portforlio value :13438.784,number of actions :1195
# Epoch :249
# Portforlio value :13407.506,number of actions :1195
# Epoch :250
# Portforlio value :13370.595,number of actions :1195
# Epoch :251
# Portforlio value :13416.285,number of actions :1195
# Epoch :252
# Portforlio value :13550.797,number of actions :1195
# Epoch :253
# Portforlio value :13550.305,number of actions :1195
# Epoch :254
# Portforlio value :13361.119,number of actions :1195
# Epoch :255
# Portforlio value :13565.336,number of actions :1195
# Epoch :256
# Portforlio value :13329.777,number of actions :1195
# Epoch :257
# Portforlio value :13372.08,number of actions :1195
# Epoch :258
# Portforlio value :13528.486,number of actions :1195
# Epoch :259
# Portforlio value :13620.726,number of actions :1195
# Epoch :260
# Portforlio value :13445.734,number of actions :1195
# Epoch :261
# Portforlio value :13156.23,number of actions :1195
# Epoch :262
# Portforlio value :13422.852,number of actions :1195
# Epoch :263
# Portforlio value :13474.497,number of actions :1195
# Epoch :264
# Portforlio value :13392.839,number of actions :1195
# Epoch :265
# Portforlio value :13378.625,number of actions :1195
# Epoch :266
# Portforlio value :13271.502,number of actions :1195
# Epoch :267
# Portforlio value :13687.459,number of actions :1195
# Epoch :268
# Portforlio value :13600.364,number of actions :1195
# Epoch :269
# Portforlio value :13840.019,number of actions :1195
# Epoch :270
# Portforlio value :13477.945,number of actions :1195
# Epoch :271
# Portforlio value :13689.577,number of actions :1195
# Epoch :272
# Portforlio value :13728.418,number of actions :1195
# Epoch :273
# Portforlio value :13600.62,number of actions :1195
# Epoch :274
# Portforlio value :13651.501,number of actions :1195
# Epoch :275
# Portforlio value :13741.036,number of actions :1195
# Epoch :276
# Portforlio value :13917.0,number of actions :1195
# Epoch :277
# Portforlio value :13899.793,number of actions :1195
# Epoch :278
# Portforlio value :13679.658,number of actions :1195
# Epoch :279
# Portforlio value :13985.394,number of actions :1195
# Epoch :280
# Portforlio value :13414.722,number of actions :1195
# Epoch :281
# Portforlio value :13550.412,number of actions :1195
# Epoch :282
# Portforlio value :13844.825,number of actions :1195
# Epoch :283
# Portforlio value :13460.591,number of actions :1195
# Epoch :284
# Portforlio value :13737.513,number of actions :1195
# Epoch :285
# Portforlio value :13559.31,number of actions :1195
# Epoch :286
# Portforlio value :13506.317,number of actions :1195
# Epoch :287
# Portforlio value :13877.661,number of actions :1195
# Epoch :288
# Portforlio value :13685.143,number of actions :1195
# Epoch :289
# Portforlio value :13471.412,number of actions :1195
# Epoch :290
# Portforlio value :13503.514,number of actions :1195
# Epoch :291
# Portforlio value :13572.557,number of actions :1195
# Epoch :292
# Portforlio value :13401.612,number of actions :1195
# Epoch :293
# Portforlio value :13754.636,number of actions :1195
# Epoch :294
# Portforlio value :13435.408,number of actions :1195
# Epoch :295
# Portforlio value :13439.963,number of actions :1195
# Epoch :296
# Portforlio value :13555.2,number of actions :1195
# Epoch :297
# Portforlio value :13678.154,number of actions :1195
# Epoch :298
# Portforlio value :13508.598,number of actions :1195
# Epoch :299
# Portforlio value :13316.502,number of actions :1195
# Epoch :300
# Portforlio value :13576.368,number of actions :1195
# Epoch :301
# Portforlio value :13328.923,number of actions :1195
# Epoch :302
# Portforlio value :13720.375,number of actions :1195
# Epoch :303
# Portforlio value :13620.412,number of actions :1195
# Epoch :304
# Portforlio value :13622.74,number of actions :1195
# Epoch :305
# Portforlio value :13846.32,number of actions :1195
# Epoch :306
# Portforlio value :13506.839,number of actions :1195
# Epoch :307
# Portforlio value :13570.721,number of actions :1195
# Epoch :308
# Portforlio value :13609.199,number of actions :1195
# Epoch :309
# Portforlio value :13324.839,number of actions :1195
# Epoch :310
# Portforlio value :13690.003,number of actions :1195
# Epoch :311
# Portforlio value :13599.062,number of actions :1195
# Epoch :312
# Portforlio value :13530.285,number of actions :1195
# Epoch :313
# Portforlio value :13449.979,number of actions :1195
# Epoch :314
# Portforlio value :13574.636,number of actions :1195
# Epoch :315
# Portforlio value :13556.367,number of actions :1195
# Epoch :316
# Portforlio value :13596.629,number of actions :1195
# Epoch :317
# Portforlio value :13394.499,number of actions :1195
# Epoch :318
# Portforlio value :13664.729,number of actions :1195
# Epoch :319
# Portforlio value :13319.569,number of actions :1195
# Epoch :320
# Portforlio value :13359.613,number of actions :1195
# Epoch :321
# Portforlio value :13423.396,number of actions :1195
# Epoch :322
# Portforlio value :13482.974,number of actions :1195
# Epoch :323
# Portforlio value :13382.67,number of actions :1195
# Epoch :324
# Portforlio value :13424.536,number of actions :1195
# Epoch :325
# Portforlio value :13443.699,number of actions :1195
# Epoch :326
# Portforlio value :13485.297,number of actions :1195
# Epoch :327
# Portforlio value :13827.191,number of actions :1195
# Epoch :328
# Portforlio value :13557.62,number of actions :1195
# Epoch :329
# Portforlio value :13730.559,number of actions :1195
# Epoch :330
# Portforlio value :13717.586,number of actions :1195
# Epoch :331
# Portforlio value :13766.199,number of actions :1195
# Epoch :332
# Portforlio value :13639.411,number of actions :1195
# Epoch :333
# Portforlio value :13772.32,number of actions :1195
# Epoch :334
# Portforlio value :13664.149,number of actions :1195
# Epoch :335
# Portforlio value :13699.336,number of actions :1195
# Epoch :336
# Portforlio value :13804.031,number of actions :1195
# Epoch :337
# Portforlio value :13463.645,number of actions :1195
# Epoch :338
# Portforlio value :13658.027,number of actions :1195
# Epoch :339
# Portforlio value :13675.364,number of actions :1195
# Epoch :340
# Portforlio value :13925.327,number of actions :1195
# Epoch :341
# Portforlio value :14059.085,number of actions :1195
# Epoch :342
# Portforlio value :13846.027,number of actions :1195
# Epoch :343
# Portforlio value :13901.223,number of actions :1195
# Epoch :344
# Portforlio value :13836.612,number of actions :1195
# Epoch :345
# Portforlio value :13713.156,number of actions :1195
# Epoch :346
# Portforlio value :13900.602,number of actions :1195
# Epoch :347
# Portforlio value :13809.751,number of actions :1195
# Epoch :348
# Portforlio value :13869.354,number of actions :1195
# Epoch :349
# Portforlio value :13828.359,number of actions :1195
# Epoch :350
# Portforlio value :13782.141,number of actions :1195
# Epoch :351
# Portforlio value :13653.445,number of actions :1195
# Epoch :352
# Portforlio value :13649.893,number of actions :1195
# Epoch :353
# Portforlio value :13527.197,number of actions :1195
# Epoch :354
# Portforlio value :13907.276,number of actions :1195
# Epoch :355
# Portforlio value :13844.3,number of actions :1195
# Epoch :356
# Portforlio value :13496.334,number of actions :1195
# Epoch :357
# Portforlio value :13692.698,number of actions :1195
# Epoch :358
# Portforlio value :13450.424,number of actions :1195
# Epoch :359
# Portforlio value :13572.129,number of actions :1195
# Epoch :360
# Portforlio value :13692.512,number of actions :1195
# Epoch :361
# Portforlio value :13366.456,number of actions :1195
# Epoch :362
# Portforlio value :13722.084,number of actions :1195
# Epoch :363
# Portforlio value :13517.479,number of actions :1195
# Epoch :364
# Portforlio value :13692.964,number of actions :1195
# Epoch :365
# Portforlio value :13543.041,number of actions :1195
# Epoch :366
# Portforlio value :13430.213,number of actions :1195
# Epoch :367
# Portforlio value :13456.885,number of actions :1195
# Epoch :368
# Portforlio value :13658.041,number of actions :1195
# Epoch :369
# Portforlio value :13741.154,number of actions :1195
# Epoch :370
# Portforlio value :13748.643,number of actions :1195
# Epoch :371
# Portforlio value :13727.121,number of actions :1195
# Epoch :372
# Portforlio value :13590.09,number of actions :1195
# Epoch :373
# Portforlio value :13669.218,number of actions :1195
# Epoch :374
# Portforlio value :13750.463,number of actions :1195
# Epoch :375
# Portforlio value :13769.918,number of actions :1195
# Epoch :376
# Portforlio value :13554.961,number of actions :1195
# Epoch :377
# Portforlio value :13728.044,number of actions :1195
# Epoch :378
# Portforlio value :13880.886,number of actions :1195
# Epoch :379
# Portforlio value :13756.598,number of actions :1195
# Epoch :380
# Portforlio value :13498.199,number of actions :1195
# Epoch :381
# Portforlio value :13593.913,number of actions :1195
# Epoch :382
# Portforlio value :13523.032,number of actions :1195
# Epoch :383
# Portforlio value :13570.999,number of actions :1195
# Epoch :384
# Portforlio value :13345.891,number of actions :1195
# Epoch :385
# Portforlio value :13597.077,number of actions :1195
# Epoch :386
# Portforlio value :13581.133,number of actions :1195
# Epoch :387
# Portforlio value :13579.971,number of actions :1195
# Epoch :388
# Portforlio value :13423.951,number of actions :1195
# Epoch :389
# Portforlio value :13543.262,number of actions :1195
# Epoch :390
# Portforlio value :13863.181,number of actions :1195
# Epoch :391
# Portforlio value :13573.055,number of actions :1195
# Epoch :392
# Portforlio value :13531.551,number of actions :1195
# Epoch :393
# Portforlio value :13622.919,number of actions :1195
# Epoch :394
# Portforlio value :13773.176,number of actions :1195
# Epoch :395
# Portforlio value :13581.569,number of actions :1195
# Epoch :396
# Portforlio value :13560.908,number of actions :1195
# Epoch :397
# Portforlio value :13727.15,number of actions :1195
# Epoch :398
# Portforlio value :13771.509,number of actions :1195
# Epoch :399
# Portforlio value :13734.252,number of actions :1195
# Epoch :400
# Portforlio value :13640.346,number of actions :1195
# Epoch :401
# Portforlio value :13611.947,number of actions :1195
# Epoch :402
# Portforlio value :13545.495,number of actions :1195
# Epoch :403
# Portforlio value :13653.103,number of actions :1195
# Epoch :404
# Portforlio value :13636.931,number of actions :1195
# Epoch :405
# Portforlio value :13872.073,number of actions :1195
# Epoch :406
# Portforlio value :13941.646,number of actions :1195
# Epoch :407
# Portforlio value :13571.093,number of actions :1195
# Epoch :408
# Portforlio value :13870.102,number of actions :1195
# Epoch :409
# Portforlio value :13655.135,number of actions :1195
# Epoch :410
# Portforlio value :13687.918,number of actions :1195
# Epoch :411
# Portforlio value :13974.97,number of actions :1195
# Epoch :412
# Portforlio value :13884.548,number of actions :1195
# Epoch :413
# Portforlio value :13719.37,number of actions :1195
# Epoch :414
# Portforlio value :13824.645,number of actions :1195
# Epoch :415
# Portforlio value :13722.988,number of actions :1195
# Epoch :416
# Portforlio value :13822.013,number of actions :1195
# Epoch :417
# Portforlio value :13958.511,number of actions :1195
# Epoch :418
# Portforlio value :13700.397,number of actions :1195
# Epoch :419
# Portforlio value :13972.808,number of actions :1195
# Epoch :420
# Portforlio value :13863.006,number of actions :1195
# Epoch :421
# Portforlio value :13743.903,number of actions :1195
# Epoch :422
# Portforlio value :13744.856,number of actions :1195
# Epoch :423
# Portforlio value :13683.569,number of actions :1195
# Epoch :424
# Portforlio value :13660.511,number of actions :1195
# Epoch :425
# Portforlio value :13793.078,number of actions :1195
# Epoch :426
# Portforlio value :13844.125,number of actions :1195
# Epoch :427
# Portforlio value :13798.664,number of actions :1195
# Epoch :428
# Portforlio value :13808.006,number of actions :1195
# Epoch :429
# Portforlio value :13838.617,number of actions :1195
# Epoch :430
# Portforlio value :13819.539,number of actions :1195
# Epoch :431
# Portforlio value :13753.313,number of actions :1195
# Epoch :432
# Portforlio value :14018.563,number of actions :1195
# Epoch :433
# Portforlio value :13745.03,number of actions :1195
# Epoch :434
# Portforlio value :13880.266,number of actions :1195
# Epoch :435
# Portforlio value :13874.234,number of actions :1195
# Epoch :436
# Portforlio value :13708.545,number of actions :1195
# Epoch :437
# Portforlio value :13681.34,number of actions :1195
# Epoch :438
# Portforlio value :13649.553,number of actions :1195
# Epoch :439
# Portforlio value :13767.78,number of actions :1195
# Epoch :440
# Portforlio value :14002.74,number of actions :1195
# Epoch :441
# Portforlio value :14044.906,number of actions :1195
# Epoch :442
# Portforlio value :13753.018,number of actions :1195
# Epoch :443
# Portforlio value :13544.437,number of actions :1195
# Epoch :444
# Portforlio value :13754.627,number of actions :1195
# Epoch :445
# Portforlio value :13820.228,number of actions :1195
# Epoch :446
# Portforlio value :13580.502,number of actions :1195
# Epoch :447
# Portforlio value :13707.262,number of actions :1195
# Epoch :448
# Portforlio value :13618.592,number of actions :1195
# Epoch :449
# Portforlio value :13761.981,number of actions :1195
# Epoch :450
# Portforlio value :13623.526,number of actions :1195
# Epoch :451
# Portforlio value :13740.983,number of actions :1195
# Epoch :452
# Portforlio value :13787.887,number of actions :1195
# Epoch :453
# Portforlio value :13792.839,number of actions :1195
# Epoch :454
# Portforlio value :13591.238,number of actions :1195
# Epoch :455
# Portforlio value :13674.195,number of actions :1195
# Epoch :456
# Portforlio value :13666.948,number of actions :1195
# Epoch :457
# Portforlio value :13524.674,number of actions :1195
# Epoch :458
# Portforlio value :13667.933,number of actions :1195
# Epoch :459
# Portforlio value :13541.87,number of actions :1195
# Epoch :460
# Portforlio value :13731.221,number of actions :1195
# Epoch :461
# Portforlio value :13618.548,number of actions :1195
# Epoch :462
# Portforlio value :13492.577,number of actions :1195
# Epoch :463
# Portforlio value :13698.675,number of actions :1195
# Epoch :464
# Portforlio value :13527.138,number of actions :1195
# Epoch :465
# Portforlio value :13574.76,number of actions :1195
# Epoch :466
# Portforlio value :13602.751,number of actions :1195
# Epoch :467
# Portforlio value :13499.764,number of actions :1195
# Epoch :468
# Portforlio value :13637.524,number of actions :1195
# Epoch :469
# Portforlio value :13542.82,number of actions :1195
# Epoch :470
# Portforlio value :13532.382,number of actions :1195
# Epoch :471
# Portforlio value :13594.874,number of actions :1195
# Epoch :472
# Portforlio value :13418.203,number of actions :1195
# Epoch :473
# Portforlio value :13538.803,number of actions :1195
# Epoch :474
# Portforlio value :13526.132,number of actions :1195
# Epoch :475
# Portforlio value :13390.225,number of actions :1195
# Epoch :476
# Portforlio value :13637.248,number of actions :1195
# Epoch :477
# Portforlio value :13448.823,number of actions :1195
# Epoch :478
# Portforlio value :13564.432,number of actions :1195
# Epoch :479
# Portforlio value :13404.025,number of actions :1195
# Epoch :480
# Portforlio value :13601.996,number of actions :1195
# Epoch :481
# Portforlio value :13592.042,number of actions :1195
# Epoch :482
# Portforlio value :13664.256,number of actions :1195
# Epoch :483
# Portforlio value :13597.835,number of actions :1195
# Epoch :484
# Portforlio value :13615.737,number of actions :1195
# Epoch :485
# Portforlio value :13491.151,number of actions :1195
# Epoch :486
# Portforlio value :13589.933,number of actions :1195
# Epoch :487
# Portforlio value :13465.541,number of actions :1195
# Epoch :488
# Portforlio value :13699.827,number of actions :1195
# Epoch :489
# Portforlio value :13516.968,number of actions :1195
# Epoch :490
# Portforlio value :13590.992,number of actions :1195
# Epoch :491
# Portforlio value :13578.082,number of actions :1195
# Epoch :492
# Portforlio value :13666.158,number of actions :1195
# Epoch :493
# Portforlio value :13364.647,number of actions :1195
# Epoch :494
# Portforlio value :13531.202,number of actions :1195
# Epoch :495
# Portforlio value :13721.879,number of actions :1195
# Epoch :496
# Portforlio value :13533.183,number of actions :1195
# Epoch :497
# Portforlio value :13701.365,number of actions :1195
# Epoch :498
# Portforlio value :13752.609,number of actions :1195
# Epoch :499
# Portforlio value :13578.887,number of actions :1195

# %%
visualize(df_train,agen.action_list,'Training set')

# %%
portforlio_history=[]
action_list=[]

env=trading_env(df_test,1)
current_state,info=env.reset()
current_state=current_state[0]
current_state=agen.convert_state(current_state)

while True:
    action=agen.decide(current_state)
    new_state,reward,terminate,truncate,_=env.step(action)

    current_state=new_state
    current_state=current_state[0]
    current_state=agen.convert_state(current_state)

    portforlio_history.append(env.total)
    action_list.append(action)

    if terminate:
        break
# Out:
# /home/golderalex2/Downloads/statistic/python/reinforce_trading/trading_environment.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['Diff_pct']=self.df['Close'].pct_change(1).fillna(0)*100

# %%
visualize(df_test,action_list,'Q-Learning')

# %%
evaluate(portforlio_history)
# Out:
# Max drawdown     4.885494
# PnL             19.923511
# ROI              0.199235
# dtype: float64
